# %%
import pandas as pd 
LSTAT = [4.98, 9.14, 4.03, 2.94, 5.33, 5.21, 12.43, 19.15, 29.93, 17.1, 20.45, 13.27, 15.71, 8.26, 10.26, 8.47, 6.58, 14.67, 11.69, 11.28, 21.02, 13.83, 18.72, 19.88, 16.3, 16.51, 14.81, 17.28, 12.8, 11.98, 22.6, 13.04, 27.71, 18.35, 20.34, 9.68, 11.41, 8.77, 10.13, 4.32, 1.98, 4.84, 5.81, 7.44, 9.55, 10.21, 14.15, 18.8, 30.81,16.2, 13.45]
RM = [6.575, 6.421, 7.185, 6.998, 7.147, 6.43, 6.012, 6.172, 5.631, 6.004, 6.377, 6.009, 5.889, 5.949, 6.096, 5.834, 5.935, 5.99, 5.456, 5.727, 5.57, 5.965, 6.142, 5.813, 5.924, 5.599, 5.813, 6.047, 6.495, 6.674, 5.713, 6.072, 5.95, 5.701, 6.096, 5.933, 5.841, 5.85, 5.966, 6.595, 7.024, 6.77, 6.169, 6.211, 6.069, 5.682, 5.786, 6.03, 5.399, 5.602, 5.963]
MEDV = [24, 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15, 18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6, 15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21, 12.7, 14.5, 13.2, 13.1, 13.5, 18.9, 20, 21, 24.7, 30.8, 34.9, 26.6, 25.3, 24.7, 21.2, 19.3, 20, 16.6, 14.4, 19.4, 19.7] 
NOX = [.538, .469, .469, .458, .458, .458, .524, .524, .524, .524, .524, .524, .524, .538, .538, .538, .538, .538, .538, .538, .538, .538, .538, .538, .538, .538, .538, .538, .538, .538, .538, .538, .538, .538, .538, .538, .499, .499, .499, .499, .428, .428, .448, .448, .448, .448, .448, .448, .448, .448, .448]


df = pd.DataFrame({"LSTAT":LSTAT, "RM":RM, "MEDV":MEDV,"NOX":NOX})
df
# Out:
#     LSTAT     RM  MEDV    NOX
# 0    4.98  6.575  24.0  0.538
# 1    9.14  6.421  21.6  0.469
# 2    4.03  7.185  34.7  0.469
# 3    2.94  6.998  33.4  0.458
# 4    5.33  7.147  36.2  0.458
# 5    5.21  6.430  28.7  0.458
# 6   12.43  6.012  22.9  0.524
# 7   19.15  6.172  27.1  0.524
# 8   29.93  5.631  16.5  0.524
# 9   17.10  6.004  18.9  0.524
# 10  20.45  6.377  15.0  0.524
# 11  13.27  6.009  18.9  0.524
# 12  15.71  5.889  21.7  0.524
# 13   8.26  5.949  20.4  0.538
# 14  10.26  6.096  18.2  0.538
# 15   8.47  5.834  19.9  0.538
# 16   6.58  5.935  23.1  0.538
# 17  14.67  5.990  17.5  0.538
# 18  11.69  5.456  20.2  0.538
# 19  11.28  5.727  18.2  0.538
# 20  21.02  5.570  13.6  0.538
# 21  13.83  5.965  19.6  0.538
# 22  18.72  6.142  15.2  0.538
# 23  19.88  5.813  14.5  0.538
# 24  16.30  5.924  15.6  0.538
# 25  16.51  5.599  13.9  0.538
# 26  14.81  5.813  16.6  0.538
# 27  17.28  6.047  14.8  0.538
# 28  12.80  6.495  18.4  0.538
# 29  11.98  6.674  21.0  0.538
# ...

# %%
from statsmodels.formula.api import ols 
Reg = ols(formula = "MEDV ~ LSTAT + RM+ NOX + LSTAT*RM*NOX", data = df)
Fit = Reg.fit()
print(Fit.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared:                       0.819
# Model:                            OLS   Adj. R-squared:                  0.790
# Method:                 Least Squares   F-statistic:                     27.84
# Date:                Mon, 28 Nov 2022   Prob (F-statistic):           5.21e-14
# Time:                        05:08:52   Log-Likelihood:                -119.32
# No. Observations:                  51   AIC:                             254.6
# Df Residuals:                      43   BIC:                             270.1
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept      -63.0089    152.215     -0.414      0.681    -369.979     243.961
# ...

# %% [markdown]
# Andrea Barreto Porcayo
#
# Fernando Pernía Méndez
#
# Joel Romero Gutiérrez

# %% [markdown]
# Conclusiones:
#
# Andrea: Con este trabajo me pude dar cuenta que con lo aprendido en clase podemos usar variables para ver si nos convien comprar casa o no comprarla, entonces es importante tomar en cuenta variables antes de de tomar una decisión solo por ver las casas, gracias a este curso en un futuro cuando queramos coprar casa podemos hacer decisiones que incluyan muchos factores y así tomar la mejor decisión.
#
# Fernando: Fue muy productivo, en nuestro caso no compraremos una casa en la localidad escogida, pero ahora que empezamos a ser independientes y que en los próximos años estaremos buscando hogar, este proyecto me abrió los ojos al ver que hay muchas variables que no tomamos en cuenta, por lo menos yo, antes de este trabajo me hubiera guiado solo por cosas sencillas como la zona, el precio y si me gustaba o no, considero que lo realizamos con un tema que es importante para todos.
#
# Joel: Lo que puedo sacar de conclusión de el proyecto es que en la vida diaria hay más de un factor que influye a la hora de realizar decisiones, como es el caso de la venta de casas. El hecho de haber un detalle como el óxido nítrico, número de cuartos, estatus y otras variantes es importante de conocerlas. Eso es lo que podemos aprender de este curso, saber reconocer el impacto que genera cada cosa en el resultado final para saber de qué modo se puede adecuar y obtener mejores condiciones.
